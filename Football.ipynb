# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# generate random integer values
from numpy.random import seed
from numpy.random import randint
from numpy.random import randn
import seaborn as sns
import statistics

# %%
source= requests.get('https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats').text
soup=BeautifulSoup(source,'lxml')
table=soup.find_all('table')

# %%
ta=table[0]
df=pd.read_html(str(ta))
df=df[0]

# %%
df
# Out:
#      Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                      Rk               Player             Nation
# 0                     1  Patrick van Aanholt             nl NED
# 1                     2           Max Aarons            eng ENG
# 2                     3     Yunis Abdelhamid             ma MAR
# 3                     4   Suleiman Abdullahi             ng NGA
# 4                     5          Mehdi Abeid             dz ALG
# ...                 ...                  ...                ...
# 2756               2651        Bongani Zungu             za RSA
# 2757               2652     Szymon Żurkowski             pl POL
# 2758               2653       David Zurutuza             es ESP
# 2759               2654      Martin Ødegaard             no NOR
# 2760               2655        Filip Đuričić             rs SRB
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
#                     Pos              Squad                Comp
# ...

# %%
df.to_excel("~/Documents/DATASETS/Football.xlsx")

# %%
df=pd.read_excel("~/Documents/DATASETS/Football.xlsx")

# %%
col=[]
for i in df.iloc[0]:
    col.append(i)

# %%
df.columns=col

# %%
df.drop(df.index[0],inplace=True)

# %%
df.iloc[0].drop
# Out:
# <bound method Series.drop of 0            1
# NaN        NaN
# Rk         NaN
# Player     NaN
# Nation     NaN
# Pos        NaN
# Squad      NaN
# Comp       NaN
# Age        NaN
# Born       NaN
# MP         NaN
# Starts     NaN
# Min        NaN
# Gls        NaN
# Ast        NaN
# PK         NaN
# PKatt      NaN
# CrdY       NaN
# CrdR       NaN
# Gls        NaN
# Ast        NaN
# G+A        NaN
# G-PK       NaN
# G+A-PK     NaN
# xG         NaN
# npxG       NaN
# xA         NaN
# xG         NaN
# xA         NaN
# xG+xA      NaN
# npxG       NaN
# npxG+xA    NaN
# Matches    NaN
# Name: 1, dtype: object>

# %%
df.drop([0], axis = 1,inplace=True)

# %%
df
# Out:
#          NaN    Rk               Player   Nation    Pos           Squad  \
# 1        NaN   NaN                  NaN      NaN    NaN             NaN
# 2        0.0     1  Patrick van Aanholt   nl NED     DF  Crystal Palace
# 3        1.0     2           Max Aarons  eng ENG     DF    Norwich City
# 4        2.0     3     Yunis Abdelhamid   ma MAR     DF           Reims
# 5        3.0     4   Suleiman Abdullahi   ng NGA  FW,MF    Union Berlin
# ...      ...   ...                  ...      ...    ...             ...
# 2758  2756.0  2651        Bongani Zungu   za RSA     MF          Amiens
# 2759  2757.0  2652     Szymon Żurkowski   pl POL     MF      Fiorentina
# 2760  2758.0  2653       David Zurutuza   es ESP     MF   Real Sociedad
# 2761  2759.0  2654      Martin Ødegaard   no NOR     MF   Real Sociedad
# 2762  2760.0  2655        Filip Đuričić   rs SRB  MF,FW        Sassuolo
#
#                     Comp  Age  Born   MP  ... G+A-PK   xG npxG   xA    xG  \
# ...

# %%
col=[]
for i in df.columns:
    col.append(i)

# %%
col[0]='A'

# %%
df.columns=col

# %%
df.drop(df['A'], axis = 1,inplace=True) 
df.index=df['Rk']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-327-e10d1c1a7c6a> in <module>
# ----> 1 df.drop(df['A'], axis = 1,inplace=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df.drop(df['Rk'], axis = 1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-337-87d4888466b4> in <module>
# ----> 1 df.drop(df['Rk'], axis = 1,inplace=True)
#       2
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df.drop(['Rk'],axis=1,inplace=True)
# Out:
# /Users/bhupendrasingh/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Rk, Player, Nation, Pos, Squad, Comp, Age, MP, Starts, Min, Gls, Ast, PK, PKatt, CrdY, CrdR, Gls90, Ast90, G+A, Gls+Ast]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Nation'] = df['Nation'].str.split(r' ').str.get(1)
# Out:
# /Users/bhupendrasingh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.drop(['Born'],axis=1,inplace=True)
# Out:
# /Users/bhupendrasingh/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df
# Out:
#                    Player Nation    Pos           Squad                Comp  \
# Rk
# 1     Patrick van Aanholt    NED     DF  Crystal Palace  eng Premier League
# 2              Max Aarons    ENG     DF    Norwich City  eng Premier League
# 3        Yunis Abdelhamid    MAR     DF           Reims          fr Ligue 1
# 4      Suleiman Abdullahi    NGA  FW,MF    Union Berlin       de Bundesliga
# 5             Mehdi Abeid    ALG     MF          Nantes          fr Ligue 1
# ...                   ...    ...    ...             ...                 ...
# 2651        Bongani Zungu    RSA     MF          Amiens          fr Ligue 1
# 2652     Szymon Żurkowski    POL     MF      Fiorentina          it Serie A
# 2653       David Zurutuza    ESP     MF   Real Sociedad          es La Liga
# 2654      Martin Ødegaard    NOR     MF   Real Sociedad          es La Liga
# 2655        Filip Đuričić    SRB  MF,FW        Sassuolo          it Serie A
#
# ...

# %%
df['Comp'] = df['Comp'].str.split(r' ').str.get(1)
# Out:
# /Users/bhupendrasingh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                    Player Nation    Pos           Squad        Comp Age  MP  \
# Rk
# 1     Patrick van Aanholt    NED     DF  Crystal Palace     Premier  28  25
# 2              Max Aarons    ENG     DF    Norwich City     Premier  19  30
# 3        Yunis Abdelhamid    MAR     DF           Reims       Ligue  31  28
# 4      Suleiman Abdullahi    NGA  FW,MF    Union Berlin  Bundesliga  22   6
# 5             Mehdi Abeid    ALG     MF          Nantes       Ligue  26  25
# ...                   ...    ...    ...             ...         ...  ..  ..
# 2651        Bongani Zungu    RSA     MF          Amiens       Ligue  26  21
# 2652     Szymon Żurkowski    POL     MF      Fiorentina       Serie  21   2
# 2653       David Zurutuza    ESP     MF   Real Sociedad          La  33   5
# 2654      Martin Ødegaard    NOR     MF   Real Sociedad          La  20  27
# 2655        Filip Đuričić    SRB  MF,FW        Sassuolo       Serie  27  21
#
# ...

# %%
df['Comp']=df['Comp'].str.replace('Premier','Premier Leauge')
df['Comp']=df['Comp'].str.replace('Ligue','Ligue1')
df['Comp']=df['Comp'].str.replace('Serie','Serie A')
df['Comp']=df['Comp'].str.replace('La','La Liga')
# Out:
# /Users/bhupendrasingh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/bhupendrasingh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/bhupendrasingh/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
df.drop(df.columns[-1],inplace=True,axis=1)
df
# Out:
# /Users/bhupendrasingh/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                    Player Nation    Pos           Squad            Comp Age  \
# Rk
# 1     Patrick van Aanholt    NED     DF  Crystal Palace  Premier Leauge  28
# 2              Max Aarons    ENG     DF    Norwich City  Premier Leauge  19
# 3        Yunis Abdelhamid    MAR     DF           Reims          Ligue1  31
# 4      Suleiman Abdullahi    NGA  FW,MF    Union Berlin      Bundesliga  22
# 5             Mehdi Abeid    ALG     MF          Nantes          Ligue1  26
# ...                   ...    ...    ...             ...             ...  ..
# 2651        Bongani Zungu    RSA     MF          Amiens          Ligue1  26
# ...

# %%
col=[]
for i in df.columns:
    col.append(i)

# %%
col[-2]='Ast90'
df.columns=col

# %%
df
# Out:
#         Rk               Player Nation    Pos           Squad            Comp  \
# 0        1  Patrick van Aanholt    NED     DF  Crystal Palace  Premier Leauge
# 1        2           Max Aarons    ENG     DF    Norwich City  Premier Leauge
# 2        3     Yunis Abdelhamid    MAR     DF           Reims          Ligue1
# 3        4   Suleiman Abdullahi    NGA  FW,MF    Union Berlin      Bundesliga
# 4        5          Mehdi Abeid    ALG     MF          Nantes          Ligue1
# ...    ...                  ...    ...    ...             ...             ...
# 2756  2651        Bongani Zungu    RSA     MF          Amiens          Ligue1
# 2757  2652     Szymon Żurkowski    POL     MF      Fiorentina         Serie A
# 2758  2653       David Zurutuza    ESP     MF   Real Sociedad         La Liga
# 2759  2654      Martin Ødegaard    NOR     MF   Real Sociedad         La Liga
# 2760  2655        Filip Đuričić    SRB  MF,FW        Sassuolo         Serie A
#
# ...

# %%
df.dropna(inplace=True)

# %%
df['Gls+Ast']=df['Gls']+df['Ast']

# %%
df
# Out:
#       Unnamed: 0    Rk               Player Nation    Pos           Squad  \
# 0              0     1  Patrick van Aanholt    NED     DF  Crystal Palace
# 1              1     2           Max Aarons    ENG     DF    Norwich City
# 2              2     3     Yunis Abdelhamid    MAR     DF           Reims
# 3              3     4   Suleiman Abdullahi    NGA  FW,MF    Union Berlin
# 4              4     5          Mehdi Abeid    ALG     MF          Nantes
# ...          ...   ...                  ...    ...    ...             ...
# 2644        2756  2651        Bongani Zungu    RSA     MF          Amiens
# 2645        2757  2652     Szymon Żurkowski    POL     MF      Fiorentina
# 2646        2758  2653       David Zurutuza    ESP     MF   Real Sociedad
# 2647        2759  2654      Martin Ødegaard    NOR     MF   Real Sociedad
# 2648        2760  2655        Filip Đuričić    SRB  MF,FW        Sassuolo
#
#                 Comp  Age  MP  Starts  ...  Gls  Ast  PK  PKatt  CrdY  CrdR  \
# ...

# %%
df
# Out:
#       Unnamed: 0    Rk               Player Nation    Pos           Squad  \
# 0              0     1  Patrick van Aanholt    NED     DF  Crystal Palace
# 1              1     2           Max Aarons    ENG     DF    Norwich City
# 2              2     3     Yunis Abdelhamid    MAR     DF           Reims
# 3              3     4   Suleiman Abdullahi    NGA  FW,MF    Union Berlin
# 4              4     5          Mehdi Abeid    ALG     MF          Nantes
# ...          ...   ...                  ...    ...    ...             ...
# 2644        2756  2651        Bongani Zungu    RSA     MF          Amiens
# 2645        2757  2652     Szymon Żurkowski    POL     MF      Fiorentina
# 2646        2758  2653       David Zurutuza    ESP     MF   Real Sociedad
# 2647        2759  2654      Martin Ødegaard    NOR     MF   Real Sociedad
# 2648        2760  2655        Filip Đuričić    SRB  MF,FW        Sassuolo
#
#                 Comp  Age  MP  Starts  ...  Gls  Ast  PK  PKatt  CrdY  CrdR  \
# ...

# %%
df=pd.read_excel("~/Documents/DATASETS/Footballl.xlsx")

# %%
print(df.max())
# Out:
# Unnamed: 0           2760
# Rk                   2655
# Player        Ștefan Radu
# Nation                ZIM
# Pos                 MF,FW
# Squad              Wolves
# Comp              Serie A
# Age                    41
# MP                     34
# Starts                 34
# Min                  3060
# Gls                    34
# Ast                    21
# PK                     11
# PKatt                  12
# CrdY                   17
# CrdR                    2
# Gls90                  10
# Ast90                 7.5
# G+A                    10
# Gls+Ast                39
# dtype: object

# %%
df
# Out:
#       Unnamed: 0    Rk               Player Nation    Pos           Squad  \
# 0              0     1  Patrick van Aanholt    NED     DF  Crystal Palace
# 1              1     2           Max Aarons    ENG     DF    Norwich City
# 2              2     3     Yunis Abdelhamid    MAR     DF           Reims
# 3              3     4   Suleiman Abdullahi    NGA  FW,MF    Union Berlin
# 4              4     5          Mehdi Abeid    ALG     MF          Nantes
# ...          ...   ...                  ...    ...    ...             ...
# 2644        2756  2651        Bongani Zungu    RSA     MF          Amiens
# 2645        2757  2652     Szymon Żurkowski    POL     MF      Fiorentina
# 2646        2758  2653       David Zurutuza    ESP     MF   Real Sociedad
# 2647        2759  2654      Martin Ødegaard    NOR     MF   Real Sociedad
# 2648        2760  2655        Filip Đuričić    SRB  MF,FW        Sassuolo
#
#                 Comp  Age  MP  Starts  ...  Gls  Ast  PK  PKatt  CrdY  CrdR  \
# ...
